# %%
import pandas as pd

df = pd.read_csv('prepped_churn_data.csv', index_col='customerID')
df
# Out:
#             tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG       1             0         1              1           29.85
# 5575-GNVDE      34             1        12              2           56.95
# 3668-QPYBK       2             1         1              2           53.85
# 7795-CFOCW      45             0        12              3           42.30
# 9237-HQITU       2             1         1              1           70.70
# ...            ...           ...       ...            ...             ...
# 6840-RESVB      24             1        12              2           84.80
# 2234-XADUH      72             1        12              4          103.20
# 4801-JZAZL      11             0         1              1           29.60
# 8361-LTMKD       4             1         1              2           74.40
# 3186-AJIEK      66             1        24              3          105.65
#
#             TotalCharges  Churn  TotalCharges_Tenure_ratio
# ...

# %%
# !conda install -c conda-forge pycaret -y
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model

# %%
automl = setup(df, target='Churn')
# Out:
# <style  type="text/css" >
#     #T_e18d679c_8e01_11ec_bd13_38f9d365ab47row5_col1 {
#             background-color:  lightgreen;
#         }    #T_e18d679c_8e01_11ec_bd13_38f9d365ab47row44_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_e18d679c_8e01_11ec_bd13_38f9d365ab47" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e18d679c_8e01_11ec_bd13_38f9d365ab47level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e18d679c_8e01_11ec_bd13_38f9d365ab47row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e18d679c_8e01_11ec_bd13_38f9d365ab47row0_col1" class="data row0 col1" >7218</td>
#             </tr>
#             <tr>
# ...

# %%
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_9d53aabe_8e01_11ec_bd13_38f9d365ab47 th {
#           text-align: left;
#     }    #T_9d53aabe_8e01_11ec_bd13_38f9d365ab47row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_9d53aabe_8e01_11ec_bd13_38f9d365ab47row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_9d53aabe_8e01_11ec_bd13_38f9d365ab47row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_9d53aabe_8e01_11ec_bd13_38f9d365ab47row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9d53aabe_8e01_11ec_bd13_38f9d365ab47row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_9d53aabe_8e01_11ec_bd13_38f9d365ab47row0_col5 {
#             text-align:  left;
# ...

# %%
best_model
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=2489)

# %%
save_model(best_model, 'ADA')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Churn',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strate...
#                  ('dummy', Dummify(target='Churn')),
#                  ('fix_perfect', Remove_100(target='Churn')),
#                  ('clean_names', Clean_Colum_Names()),
# ...

# %%
from IPython.display import Code

Code('predict_churn.py')
# Out:
# import pandas as pd
# from pycaret.classification import predict_model, load_model
# model = load_model('GBC')
# def load_data(filepath):
#     df = pd.read_csv(filepath, index_col='customerID')
#     return df
#
# def make_predictions(df):
#     model = load_model('GBC')
#     predictions = predict_model(model, data=df)
#     predictions.rename({'Label': 'Churn_prediction'}, axis=1, inplace=True)
#     predictions['Churn_prediction'].replace({1: 'Churn', 0: 'No churn'},
#                                             inplace=True)
#     return predictions['Churn_prediction']
#
# if __name__ == "__main__":
#     df = load_data('churn_data.csv')
#     predictions = make_predictions(df)
#     print('predictions:')
#     print(predictions)

# %%
# %run predict_churn.py
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Downloads/predict_churn.py in <module>
#      16 if __name__ == "__main__":
#      17     df = load_data('churn_data.csv')
# ---> 18     predictions = make_predictions(df)
#      19     print('predictions:')
#      20     print(predictions)
#
# ~/Downloads/predict_churn.py in make_predictions(df)
#       8 def make_predictions(df):
#       9     model = load_model('GBC')
# ---> 10     predictions = predict_model(model, data=df)
#      11     predictions.rename({'Label': 'Churn_prediction'}, axis=1, inplace=True)
#      12     predictions['Churn_prediction'].replace({1: 'Churn', 0: 'No churn'},
#
# ...

# %% [markdown]
# Using pycaret showed that the best ML algorithm that performed the best with the data was the AdaBoostClassifier and this was determined using accuracy. The model was saved using pickle file
# A python script was created using jupyter notebook. Unfortunately I was not able to run the code successfully for predictions for the new data. I tried fixing the error of ""['TotalCharges_Tenure_ratio'] not in index" but I could not and this is why my code was unable to run properly
